# %%
import matplotlib.pyplot as plot

t_1 = 10
t_2 = 20

# X1 = 0.879738
# X2 = 1.3127
# X3 = 0.879738


# Real Solutions
X1 = -0.203636
X2 = -0.859796
X3 = -0.203636
a_2 = (1 / (2 * t_2)) * (((3*(X2 - X1)*(t_2 + t_1)) / (t_1**2)) - ((3*(X3 - X2))/ (t_2 - t_1)))
a_3 = (1 / t_1) * (-a_2 + ((X2 - X1) / (t_1**2)))

a_0= X1
b_0= X2
a_1 = 0

b_1= 2*a_2*t_1+3*a_3*t_1*t_1
b_2= a_2+3*a_3*t_1
b_3= (-1 / (3*(t_2 - t_1)**2)) * (b_1 + 2*b_2*(t_2-t_1))


print(a_0, a_1, a_2, a_3)
print(b_0, b_1, b_2, b_3)

#Jordans Solutions
# X0 = 0.879738
# X1 = 1.3127
# X2 = 0.879738
#
# a_0= X0
# b_0= X1
# a_1 = 0
#
# b_3_top = ((3*t_2*t_2*X1) - (3*t_2*t_2*X0) - (2*t_2*t_1*X1) + (6*t_2*t_1*X0) - (4*t_2*t_1*X2) - (3*t_1*t_1*X0) + (3*t_1*t_1*X2))
# b_3_bottom = (((t_2-t_1)**2)*((2*t_2*t_2*t_1) + 5*t_2*t_1*t_1))
# b_3 = b_3_top / b_3_bottom
#
# b_2 = (-2 * (t_2 - t_1) * b_3) + ((X1 - X2) / ((t_2 - t_1) ** 2))
# b_1 = ((t_2 - t_1)**2)*b_3 + (((2*X2) - (2*X1))/(t_2 - t_1))
# a_3 = (((-(t_2**2) - (2*t_2*t_1) + (3*t_1*t_1)) / (3*t_1*t_1)) * b_3) + (((2*t_2*X1) - (2*t_2*X2)) / ((3*t_1*t_1)*((t_2-t_1)**2)))
# a_2 = (((((t_2*t_2)-(t_1*t_1))/t_1) * b_3) + (((t_1*X1) - (2*t_2*X1) - (t_1*X2) + (2*t_2*X2)) / (((t_2 - t_1) ** 2) * t_1)))


# Solution with C
# X0 = -0.203636
# X1 = -0.859796
# X2 = -0.203636
#
# a_0= X0
# b_0= X1
# a_1 = 0
#
# C = ((2/3)*t_1*t_2) - (t_1 * t_1) + ((1/3)*t_2*t_2)
# a_3_top = (X2 - X1 - ((X1 * C)/t_1) + ((X0 * C)/t_1))
# a_3_bottom = (-((t_1**2)*C) - ((7/3) * t_1 * t_1 * t_2) - ((1/3) * (t_1**3)) + ((8/3)*t_1*t_2*t_2))
# a_3 = a_3_top / a_3_bottom
#
# a_2 = ((X1 - X0 - (a_3 * (t_1 ** 3))) / (t_1 ** 2))
#
# b_1 = (2 * a_2 * t_1) + (3 * a_3 * t_1 * t_1)
# b_2 = a_2 + (3*a_3*t_1)

# b_3_left = (((a_3*t_1)*(t_1 - (2 * t_2))) / (3*((t_2 - t_1) ** 2)))
# b_3_right = ((2*a_2*t_2) / (3*((t_2 -t_1) ** 2)))
# b_3 = b_3_left - b_3_right

# b_3= (-1 / (3*(t_2 - t_1)**2)) * (b_1 + 2*b_2*(t_2-t_1))


# New Solution
X0 = 0.867466
X1 = 1.3127
X2 = 1.867466

a_0= X0
b_0= X1
a_1 = 0

a_2 = (-3 * (X2 - X1) / (2 * t_2 * (t_2 - t_1)) + ((3 * (t_1 + t_2) * (X1 - X0)) / (2 * t_1 * t_1 * t_2)))

# a_2 = (1 / (2 * t_2)) * (((3*(X2 - X1)*(t_2 + t_1)) / (t_1**2)) - ((3*(X3 - X2))/ (t_2 - t_1)))

a_3 = (X1 - X0 - (a_2 * t_1 * t_1)) / (t_1 ** 3)

b_1 = (2 * a_2 * t_1) + (3 * a_3 * (t_1 ** 2))
b_2 = a_2 + (3 * a_3 * t_1)
b_3 = ((X2 - X1) / ((t_2 - t_1) ** 3)) - (b_1 / ((t_2 - t_1) ** 2)) - (b_2 / (t_2 - t_1))

# Old Solutions
# b_2 = (3*(t_2*(X1-X0) + t_1*(X0-X2))/(t_1*t_2*(t_1 - t_2)))
# b_2_top = ((3 * X2) - (3  * X0) - (3 * t_2 * ((X1-X0)/t_1)))
# b_2_bottom = (t_1 * t_2) - (t_2 * t_2)
# b_2 = -(b_2_top / b_2_bottom)
#
#
#
# b_1 = (-3*(X0-X1) + b_2*t_1*t_1) / (2*t_1)
# b_3 = (-b_1 - (2*b_2*(t_2-t_1)))/(3*(t_2 - t_1)*(t_2 - t_1))
# b_0 = X1
#
# a_0 = X0
# a_1 = 0
# a_2 = -(((t_1 * b_2) - b_1) / t_1)
# a_3 = ((2*t_1*b_2) - b_1) / 3*t_1*t_1

print(a_0, a_1, a_2, a_3)
print(b_0, b_1, b_2, b_3)

print(b_2, a_2 + 3*a_3*t_1)

def x_1(t):
    return a_0 + (a_1 * t) + (a_2 * t * t) + (a_3 * t * t * t)

def x_2(t):
    return b_0 + (b_1 * (t - t_1)) + (b_2 * (t - t_1) * (t - t_1)) + (b_3 * (t - t_1) * (t - t_1) * (t - t_1))

transition_1 = [x_1(t) for t in range(0, t_1)]
transition_2 = [x_2(t) for t in range(t_1, t_2)]

points = transition_1 + transition_2
print(points)
plot.plot(points)
plot.show()
# Out:
# -0.203636 0 -0.019684800000000002 0.0013123200000000003
# -0.859796 0.0 0.019684800000000002 -0.0013123200000000003
# 0.867466 0 0.005857020000000001 -0.00014046800000000004
# 1.3127 0.07500000000000001 0.0016429799999999996 -0.000359532
# 0.0016429799999999996 0.0016429799999999996
# [0.867466, 0.873182552, 0.8897703359999999, 0.916386544, 0.952188368, 0.9963329999999999, 1.047977632, 1.106279456, 1.1703956640000002, 1.239483448, 1.3127, 1.3889834479999998, 1.466395664, 1.542779456, 1.615977632, 1.683833, 1.744188368, 1.7948865440000001, 1.8337703360000002, 1.8586825519999999]
