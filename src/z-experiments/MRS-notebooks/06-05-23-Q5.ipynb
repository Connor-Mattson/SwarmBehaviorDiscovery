# %% [markdown]
# # Establish Need for Improvement over Baselines.
#
# ## Q5: For a uniform sampling under a 9-dimensional controller, what is the distribution of heterogeneous behaviors retrieved?

# %%
# Hand-Recorded Sampling Results taken by C.M.
SAMPLING_RESULTS = {
    "Random" : 105,
    "Segments": 0,
    "Nucleus": 8,
    "Containment" : 5,
    "Spiral" : 1,
    "Nested Cycles" : 3,
    "Perimeter" : 0,
    "Site Traversal" : 0,
    "Flail" : 0,
    "Hurricane" : 0,
    "Snake" : 5,
    "Leader" : 0,
    "Dipole" : 1,
    "Aggregation" : 6,
    "Cyclic Pursuit" : 1,
    "Dispersal" : 10,
    "Milling" : 0,
    "Wall-F" : 0,
    "Disp+Aggr" : 5
}

# %%
import matplotlib.pyplot as plt

x = [i for i in range(len(SAMPLING_RESULTS))]
y = list(SAMPLING_RESULTS.values())
labels = list(SAMPLING_RESULTS.keys())

plt.bar(x, y, color=(0.5, 0, 0))
plt.xticks(x, labels, rotation=45, horizontalalignment="right")
plt.xlabel("Collective Behavior")
plt.ylabel("Count")
plt.title("Uniform Sampling Rates of Collective Swarm Behaviors under 150 Heterogeneous Controllers")
plt.show()
